# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
activision = pd.DataFrame([2480,2690,2855,3001,3154,3308,3465,3718,3851,4006,4169,4363,4480,4603], 
                    index=["2017Q1","2017Q2","2017Q3","2017Q4","2018Q1","2018Q2","2018Q3","2018Q4","2019Q1","2019Q2",
                          "2019Q3","2019Q4","2020Q1","2020Q2",])

# %%
activision.plot(title="Dayforce Customers Live", legend=False)
# Out:
# C:\Users\chiugabr\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:title={'center':'Dayforce Customers Live'}>

# %%
x = [20,12.3,8.84,7.74,22]
y = [63.74,18.22,10.74,17.51,43.06]
sns.set()
n = ["CDAY", "ADP", "ORCL", "SAP", "WDAY"]


m, b = np.polyfit(x, y, 1)




fig, ax = plt.subplots()
ax.plot(x, y)
plt.plot(x, m*x + b)

plt.xlabel("Growth rate (%)")
plt.ylabel("EV/EBITDA forward 12M")

for i, txt in enumerate(n):
    ax.annotate(txt, (x[i], y[i]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-f0205146d07b> in <module>
#      11 fig, ax = plt.subplots()
#      12 ax.plot(x, y)
# ---> 13 plt.plot(x, m*x + b)
#      14
#      15 plt.xlabel("Growth rate (%)")
#
# TypeError: can't multiply sequence by non-int of type 'numpy.float64'

# %%
x = [20,12.3,8.84,7.74,22]
y = [63.74,18.22,10.74,17.51,43.06]
sns.set()
n = ["CDAY", "ADP", "ORCL", "SAP", "WDAY"]

fig, ax = plt.subplots(figsize=(7,5))
ax.scatter(x, y)

plt.xlabel("Growth rate (%)")
plt.ylabel("EV/EBITDA forward 12M")

for i, txt in enumerate(n):
    ax.annotate(txt, (x[i], y[i]))
    
sns.regplot(x,y, ci=None)
plt.xlim([6, 24])
plt.ylim([8, 70])
# Out:
# (8.0, 70.0)

# %% [markdown]
# Zynga

# %%
temp = pd.DataFrame([21,21,21,22,25,23,22,22,22,21,20,20,21,22,34,39], 
                    index=["2017Q1","2017Q2","2017Q3","2017Q4","2018Q1","2018Q2","2018Q3","2018Q4","2019Q1","2019Q2",
                          "2019Q3","2019Q4","2020Q1","2020Q2","2020Q3","2020Q4"])

# %%
sns.set()
fig = temp.plot(title="Daily Active Users", legend=False)
# Out:
# C:\Users\chiugabr\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
df2 = pd.DataFrame([np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,34,39], 
                   index=["2017Q1","2017Q2","2017Q3","2017Q4","2018Q1","2018Q2","2018Q3","2018Q4","2019Q1","2019Q2",
                          "2019Q3","2019Q4","2020Q1","2020Q2","2020Q3","2020Q4"])

# %%
sns.set()
fig = temp.plot(title="Daily Active Users", legend=False)
df2.plot(ax=fig, style="-.", legend=False, color="gold")
# Out:
# C:\Users\chiugabr\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:title={'center':'Daily Active Users'}>

# %%
barWidth = 0.2
strategy = [0.285,0.138,0.084,0.052,0.027]
casual=[0.309,0.151,0.09,0.054,0.028]
hyperCasual=[0.327,0.157,0.088,0.05,0.023]
socialCasino=[0.322,0.171,0.11,0.072,0.042]

r1=np.arange(len(strategy))
r2=[x+barWidth for x in r1]
r3=[x+barWidth for x in r2]
r4=[x+barWidth for x in r3]

# %%
sns.set()
plt.figure(figsize=(10,5))
plt.bar(r1, strategy, color="darkblue", width=barWidth, edgecolor="white", label="Strategy")
plt.bar(r2, casual, color="gold", width=barWidth, edgecolor="white", label="Casual")
plt.bar(r3, hyperCasual, color="black", width=barWidth, edgecolor="white", label="HyperCasual")
plt.bar(r4, socialCasino, color="wheat", width=barWidth, edgecolor="white", label="SocialCasino")

plt.xticks([r+barWidth for r in range(len(strategy))], ["Day 1", "Day 3", "Day 7", "Day 14", "Day 30"])
plt.legend()
plt.title("Retention Rate")
plt.show()

# %%
sns.set()
plt.figure()
plt.pie(x=[0.25,0.2,0.24,0.22,0.09],labels=["Empires & Puzzles", "Merge Dragons!", "Other Forever Franchises", 
                                            "Social Slots & Casual Card Game", "Other"],
        colors=["darkblue", "gold", "black", "blue", "wheat"], explode=[0.05,0.05,0.05,0.05,0.05],autopct="%.1f%%",
        textprops=dict(color="w"))
plt.title("ZNGA 2020Q2 Revenue Composition")
# Out:
# Text(0.5, 1.0, 'ZNGA 2020Q2 Revenue Composition')

# %%
mobileGameSpend = pd.DataFrame([30,37,47.4,54.7,61.7,76], 
                    index=["2015","2016","2017","2018","2019","Projected 2020"])
ax=mobileGameSpend.plot(title="Mobile Gaming Spend (USD Billions)", legend=False)
dfProject = pd.DataFrame([np.nan,np.nan,np.nan,np.nan,61.7,76],
                        index=["2015","2016","2017","2018","2019","Projected 2020"])
dfProject.plot(ax=ax,style="-.", legend=False, color="gold")
# Out:
# C:\Users\chiugabr\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:title={'center':'Mobile Gaming Spend (USD Billions)'}>

# %%
mobileGameSpend = pd.DataFrame([1.8,1.8,1.7,2.1], 
                    index=["2016 Q3","2017 Q3","2018 Q3","2019 Q3"])
mobileGameSpend.plot(title="ZNGA's share of Revenue", legend=False)
# Out:
# C:\Users\chiugabr\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:title={'center':"ZNGA's share of Revenue"}>
