# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from pandas_datareader import data
import scipy.optimize as sco
from datetime import date

# %%
csvFile = pd.read_csv("Tickers.csv")
# drop RUB denominated as unable to programatically find FX rate
csvFile = csvFile[csvFile.Currency!="RUB"]
csvFile.reset_index(drop=True, inplace=True)

# %%
# FX translation
usdAUD = data.DataReader("DEXUSAL","fred") # convention USD/AUD
usdEUR = data.DataReader("DEXUSEU","fred") # convention EUR/USD
usdCHF = data.DataReader("DEXSZUS","fred") # convention CHF/USD
usdDKK = data.DataReader("DEXDNUS","fred") # convention DKK/USD
usdJPY = data.DataReader("DEXJPUS","fred") # convention JPY/USD
usdHKD = data.DataReader("DEXHKUS","fred") # convention HKD/USD
usdBRL = data.DataReader("DEXBZUS","fred") # convention BRL/USD

# %% [markdown]
# Currently the script is designed to only work a single market at a time. Specifically it drops all non-US stocks from the investment universe defined in the variable "csvFile".
#
# Next steps: incorporate FX translations and date adjustments (differing holidays mean different markets are closed at different times for example) between the different markets so that it can handle a global investment universe

# %%
# divide tickers by geography
usTicker = []
for i in csvFile.index:
    if csvFile.Currency.iloc[i] == "USD":
        usTicker.append(csvFile.Ticker.iloc[i])

# %%
start = date(2000,1,1)
end = date(2020,10,16)
usTickersData = data.DataReader(usTicker,start=start, end = end, data_source="yahoo")["Adj Close"]
#usTickersData = usTickersData.dropna(axis='rows')
returns = usTickersData.pct_change()
expected_returns = returns.mean()
cov_matrix = returns.cov()

# %%
def portfolio_performance(weights, expected_returns, cov_matrix):
    """
    Returns the portfolio's expected return and standard deviation
    
    expected returns and cov_matrix variables are expected to be daily values
    
    weights variables -- pandas dataframe
    """

    pf_return = np.sum(weights*expected_returns)*252
    pf_std = np.sqrt(np.dot(weights.T,np.dot(cov_matrix, weights)))*np.sqrt(252)
    return pf_return, pf_std

def negative_sharpe(weights, expected_returns, cov_matrix, risk_free):
    '''
    Calculates the negative Sharpe ratio
    args:
    weights -- portfolio weights
    expected_ returns -- mean returns
    cov_matrix -- covariance matrix
    risk_free -- risk free rate
    '''
    pf_return, pf_std = portfolio_performance(weights, expected_returns, cov_matrix)
    neg_sharpe = - (pf_return - risk_free)/pf_std
    return neg_sharpe

def portfolio_vol(weights, expected_returns, cov_matrix):
    return portfolio_performance(weights, expected_returns, cov_matrix)[1]

def max_sharpe_ratio(expected_returns, cov_matrix, risk_free):
    """
    Calculates the maximimum sharpe ratio portfolio by formulating an optimization problem.
    """
    size_portfolio = expected_returns.count()
    bounds = tuple((0, 1) for x in range(size_portfolio))
    constraints = ({'type': 'eq', 'fun': lambda x: np.sum(x) -1})
    scale = size_portfolio * [1./size_portfolio] # initialize at equal weights
    args = (expected_returns, cov_matrix, risk_free) #args to be passed to optimising function
    results = sco.minimize(negative_sharpe, scale, args=args, method="SLSQP", bounds=bounds, constraints=constraints)
    return results

def min_var(expected_returns, cov_matrix):
    """
    Calculates the minimum variance portfolio by formulating an optimization problem.
    """
    size_portfolio = expected_returns.count()
    bounds = tuple((0, 1) for x in range(size_portfolio))
    constraints = ({'type': 'eq', 'fun': lambda x: np.sum(x) -1})
    scale = size_portfolio * [1./size_portfolio] # initialize at equal weights
    args = (expected_returns, cov_matrix) #args to be passed to optimising function
    results = sco.minimize(portfolio_vol, scale, args=args, method="SLSQP", bounds=bounds, constraints=constraints)
    return results

def portfolio_return(weights, expected_returns, cov_matrix):
    return portfolio_performance(weights, expected_returns, cov_matrix)[0]

def eff_return(expected_returns, cov_matrix, target_return):
    '''
    Calculate the optimal portfolio construction for target_return
    '''
    
    size_portfolio = expected_returns.count()
    constraints = ({'type':'eq','fun': lambda x:portfolio_return(x, expected_returns, cov_matrix)-target_return},
                   {'type':'eq', 'fun': lambda x:np.sum(x)-1})
    bounds = tuple((0, 1) for x in range(size_portfolio))
    scale = size_portfolio * [1./size_portfolio] # initialize at equal weights
    args = (expected_returns, cov_matrix) #args to be passed to optimising function
    results = sco.minimize(portfolio_vol, scale, args=args, method="SLSQP", bounds=bounds, constraints=constraints)
    return results

def eff_frontier(expected_returns, cov_matrix, target_range):
    '''
    
    args:
    expected_returns -- 
    cov_matrix -- 
    target_range -- list of returns to plot
    
    '''
    graph = []
    for target in target_range:
        graph.append(eff_return(expected_returns, cov_matrix, target))
    return graph

def mvo(expected_returns, cov_matrix):
    '''
    Construction of the efficient frontier by applying a linear combination of the Max Sharpe and Min Var portfolios
    This function does not allow short-selling in its estimation.
    
    '''
    
    max_sharpe = max_sharpe_ratio(expected_returns, cov_matrix, 0.01)
    ms_return, ms_std = portfolio_performance(max_sharpe['x'], expected_returns, cov_matrix)
    ms_weights = [round(i*100,2) for i in max_sharpe['x']] 
    ms_allocation = pd.DataFrame(ms_weights, index = expected_returns.index, columns = ['allocation'])
    ms_allocation = ms_allocation[ms_allocation != 0].dropna()
    
    minvar = min_var(expected_returns, cov_matrix)
    mv_return, mv_std = portfolio_performance(minvar['x'], expected_returns, cov_matrix)
    mv_weights = [round(i*100,2) for i in minvar['x']]
    mv_allocation = pd.DataFrame(mv_weights, index = expected_returns.index, columns = ['allocation'])
    mv_allocation = mv_allocation[mv_allocation != 0].dropna()
    
    
    with pd.option_context('display.max_rows', None, 'display.max_columns', None):
        print("Max Sharpe Portfolio Allocation")
        print("Expected return: ", ms_return)
        print("Standard deviation: ", ms_std)
        print(ms_allocation.T)
        print("Min Variance Portfolio Allocation")
        print("Expected return: ", mv_return)
        print("Standard deviation: ", mv_std)
        print(mv_allocation.T)
        
    graph = eff_frontier(expected_returns, cov_matrix, np.linspace(0.1,0.60,40))
    
    scttr_plt = np.zeros((2,40))
    i = 0
    for weights in graph:
        temp_return, temp_std = portfolio_performance(weights['x'], expected_returns, cov_matrix)
        scttr_plt[0,i] = temp_return
        scttr_plt[1,i] = temp_std
        i += 1

    
    plt.figure(figsize=(10,7))
    plt.scatter(scttr_plt[1,:], scttr_plt[0,:], marker='o')
    plt.scatter(ms_std, ms_return, marker="*", color="b", s=100, label="Max Sharpe")
    plt.scatter(mv_std, mv_return, marker="*", color="r", s=100, label = "Min Var")
    plt.xlabel('Annualized volatility')
    plt.ylabel('Annualized return')

# %% [markdown]
# The below plot shows the efficient frontier for an unconstrained mean variance optimization efficient frontier

# %%
mvo(expected_returns, cov_matrix)
# Out:
# Max Sharpe Portfolio Allocation
# Expected return:  1.5342690079141563
# Standard deviation:  0.316415520682537
# Symbols     BILL  MITK  TWLO   LSPD   FOUR  PAYS    LX   CNF    DNB
# allocation  7.51  0.17  1.83  53.88  19.96  0.55  0.37  0.64  15.09
# Min Variance Portfolio Allocation
# Expected return:  0.14356081401150056
# Standard deviation:  0.15498791199553807
# Symbols      FIS  FISV    BKI  GWRE   VIRT  MITK  TCEHY   ICE  AAPL    FB  \
# allocation  2.37   0.6  15.53  0.21  15.62  0.05   3.48  1.01  0.09  2.98
#
# Symbols      TSM  DISCA   HDB   VRSK    WU  EVTC  PAYS  UEPS    JT   EFX  \
# allocation  0.83   1.91  0.98  22.32  3.37  0.12   0.1  0.69  1.13  3.52
#
# Symbols      XYF  AIHS    HX   CNF  CLGX   JFU    DNB
# allocation  3.44  0.17  1.11  3.73  0.32  0.47  13.84

# %% [markdown]
# This variation of the MVO portfolio adds a maximum concentration variable to constrain the weight allocation.
#
# One reason you to consider constraining the maximum weight of a stock is to force the portfolio to diversify its holdings. Otherwise, a portfolio can end up with concentrated exposure to a few select stocks. For example, the Minimum Variance portfolio above has 27 positions, meaning the average weight is 3.7% but the portfolio is highly concentrated in VIRT at 15.62%, VRS at 22.32%, DNB at 13.84%. Those 3 stocks by themselves account for more than half the portfolio weight

# %%
def constrainedMVO(expected_returns, cov_matrix, target_return, max_concentration):
    '''
    Construction of the efficient frontier by applying a linear combination of the Max Sharpe and Min Var portfolios
    This function does not allow short-selling in its estimation.
    
    no position can exceed the max_concentration
    
    '''
    
    size_portfolio = expected_returns.count()
    constraints = ({'type':'eq','fun': lambda x:portfolio_return(x, expected_returns, cov_matrix)-target_return},
                   {'type':'eq', 'fun': lambda x:np.sum(x)-1},
                   {'type':'ineq', 'fun':  lambda x:max_concentration-x})
    bounds = tuple((0, 1) for x in range(size_portfolio))
    scale = size_portfolio * [1./size_portfolio] # initialize at equal weights
    args = (expected_returns, cov_matrix) #args to be passed to optimising function
    results = sco.minimize(portfolio_vol, scale, args=args, method="SLSQP", bounds=bounds, constraints=constraints)
    
    portfolio_weights = results["x"].round(2)
    return pd.DataFrame(portfolio_weights, index=expected_returns.index, columns=["Weights"])
    
def surfaceMVO(expected_returns, cov_matrix, max_target, draw=True):
    '''
    generate an efficient surface over a range of target returns constrained by an upper limit on any single stock position
    '''
    
    # Vary the target return
    target_range = np.linspace(0,max_target,1000)
    concentration_range = np.linspace(0.05, 0.25, 1000)
    
    graph = []
    for target in target_range:
        print("Progress currently at {0}%".format(round(target/max_target*100,2)))
        for concentration in concentration_range:
            # data to scatterplot the 3D surface
            temp_weights = constrainedMVO(expected_returns, cov_matrix, target, concentration)
            temp_return, temp_std = portfolio_performance(temp_weights.Weights, expected_returns, cov_matrix)
            graph.append([temp_return, temp_std, concentration, temp_weights])
            
    if draw:
        scttr_plt = np.zeros((3,2500))
        i = 0
        for weights in graph:
            scttr_plt[0,i] = graph[i][0]
            scttr_plt[1,i] = graph[i][1]
            scttr_plt[2,i] = graph[i][2]
            i += 1
        fig = plt.figure(figsize=(10,7))
        ax = fig.add_subplot(111,projection="3d")
        ax.scatter3D(xs=scttr_plt[0,:], ys=scttr_plt[1,:], zs=scttr_plt[2,:], c=scttr_plt[2,:], marker=".", cmap='plasma',s=200, alpha=0.3)
        ax.view_init(elev=0, azim=0)
        ax.invert_xaxis()

        ax.set_xlabel("Return")
        ax.set_ylabel("Volatility")
        ax.set_zlabel("Max Position Concentration")
    return graph

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
scttr_plt = np.zeros((2,2500))
i = 0
for weights in graph:
    temp_return, temp_std = portfolio_performance(weights.Weights, expected_returns, cov_matrix)
    scttr_plt[0,i] = temp_return
    scttr_plt[1,i] = temp_std
    i += 1

# %%
graph = surfaceMVO(expected_returns, cov_matrix, 0.3, 0.15)
# Out:
# Currently working on return target: 0.0%
# Currently working on return target: 0.0012048192771084336%
# Currently working on return target: 0.0024096385542168672%
# Currently working on return target: 0.003614457831325301%
# Currently working on return target: 0.0048192771084337345%
# Currently working on return target: 0.006024096385542168%
# Currently working on return target: 0.007228915662650602%
# Currently working on return target: 0.008433734939759036%
# Currently working on return target: 0.009638554216867469%
# Currently working on return target: 0.010843373493975902%
# Currently working on return target: 0.012048192771084336%
# Currently working on return target: 0.01325301204819277%
# Currently working on return target: 0.014457831325301203%
# Currently working on return target: 0.015662650602409636%
# Currently working on return target: 0.016867469879518072%
# Currently working on return target: 0.018072289156626505%
# Currently working on return target: 0.019277108433734938%
# Currently working on return target: 0.02048192771084337%
# Currently working on return target: 0.021686746987951804%
# Currently working on return target: 0.02289156626506024%
# Currently working on return target: 0.024096385542168672%
# Currently working on return target: 0.025301204819277105%
# Currently working on return target: 0.02650602409638554%
# Currently working on return target: 0.027710843373493974%
# Currently working on return target: 0.028915662650602407%
# Currently working on return target: 0.03012048192771084%
# Currently working on return target: 0.03132530120481927%
# Currently working on return target: 0.03253012048192771%
# Currently working on return target: 0.033734939759036145%
# Currently working on return target: 0.034939759036144574%
# Currently working on return target: 0.03614457831325301%
# Currently working on return target: 0.03734939759036144%
# Currently working on return target: 0.038554216867469876%
# Currently working on return target: 0.03975903614457831%
# Currently working on return target: 0.04096385542168674%
# Currently working on return target: 0.04216867469879518%
# Currently working on return target: 0.04337349397590361%
# Currently working on return target: 0.04457831325301204%
# Currently working on return target: 0.04578313253012048%
# Currently working on return target: 0.04698795180722891%
# Currently working on return target: 0.048192771084337345%
# Currently working on return target: 0.04939759036144578%
# Currently working on return target: 0.05060240963855421%
# Currently working on return target: 0.05180722891566265%
# Currently working on return target: 0.05301204819277108%
# Currently working on return target: 0.05421686746987951%
# Currently working on return target: 0.05542168674698795%
# Currently working on return target: 0.05662650602409638%
# Currently working on return target: 0.057831325301204814%
# Currently working on return target: 0.05903614457831325%
# Currently working on return target: 0.06024096385542168%
# Currently working on return target: 0.061445783132530116%
# Currently working on return target: 0.06265060240963854%
# Currently working on return target: 0.06385542168674699%
# Currently working on return target: 0.06506024096385542%
# Currently working on return target: 0.06626506024096385%
# Currently working on return target: 0.06746987951807229%
# Currently working on return target: 0.06867469879518072%
# Currently working on return target: 0.06987951807228915%
# Currently working on return target: 0.07108433734939758%
# Currently working on return target: 0.07228915662650602%
# Currently working on return target: 0.07349397590361445%
# Currently working on return target: 0.07469879518072288%
# Currently working on return target: 0.07590361445783132%
# Currently working on return target: 0.07710843373493975%
# Currently working on return target: 0.07831325301204818%
# Currently working on return target: 0.07951807228915662%
# Currently working on return target: 0.08072289156626505%
# Currently working on return target: 0.08192771084337348%
# Currently working on return target: 0.08313253012048193%
# Currently working on return target: 0.08433734939759036%
# Currently working on return target: 0.08554216867469878%
# Currently working on return target: 0.08674698795180721%
# Currently working on return target: 0.08795180722891566%
# Currently working on return target: 0.08915662650602409%
# Currently working on return target: 0.09036144578313252%
# Currently working on return target: 0.09156626506024096%
# Currently working on return target: 0.09277108433734939%
# Currently working on return target: 0.09397590361445782%
# Currently working on return target: 0.09518072289156626%
# Currently working on return target: 0.09638554216867469%
# Currently working on return target: 0.09759036144578312%
# Currently working on return target: 0.09879518072289156%
# Currently working on return target: 0.09999999999999999%
# Currently working on return target: 0.10120481927710842%
# Currently working on return target: 0.10240963855421686%
# Currently working on return target: 0.1036144578313253%
# Currently working on return target: 0.10481927710843372%
# Currently working on return target: 0.10602409638554217%
# Currently working on return target: 0.1072289156626506%
# Currently working on return target: 0.10843373493975902%
# Currently working on return target: 0.10963855421686745%
# Currently working on return target: 0.1108433734939759%
# Currently working on return target: 0.11204819277108433%
# Currently working on return target: 0.11325301204819276%
# Currently working on return target: 0.1144578313253012%
# Currently working on return target: 0.11566265060240963%
# Currently working on return target: 0.11686746987951806%
# Currently working on return target: 0.1180722891566265%
# Currently working on return target: 0.11927710843373493%
# Currently working on return target: 0.12048192771084336%
# Currently working on return target: 0.1216867469879518%
# Currently working on return target: 0.12289156626506023%
# Currently working on return target: 0.12409638554216866%
# Currently working on return target: 0.1253012048192771%
# Currently working on return target: 0.12650602409638553%
# Currently working on return target: 0.12771084337349398%
# Currently working on return target: 0.1289156626506024%
# Currently working on return target: 0.13012048192771083%
# Currently working on return target: 0.13132530120481928%
# Currently working on return target: 0.1325301204819277%
# Currently working on return target: 0.13373493975903614%
# Currently working on return target: 0.13493975903614458%
# Currently working on return target: 0.136144578313253%
# Currently working on return target: 0.13734939759036144%
# Currently working on return target: 0.13855421686746985%
# Currently working on return target: 0.1397590361445783%
# Currently working on return target: 0.14096385542168674%
# Currently working on return target: 0.14216867469879516%
# Currently working on return target: 0.1433734939759036%
# Currently working on return target: 0.14457831325301204%
# Currently working on return target: 0.14578313253012046%
# Currently working on return target: 0.1469879518072289%
# Currently working on return target: 0.14819277108433734%
# Currently working on return target: 0.14939759036144576%
# Currently working on return target: 0.1506024096385542%
# Currently working on return target: 0.15180722891566265%
# Currently working on return target: 0.15301204819277106%
# Currently working on return target: 0.1542168674698795%
# Currently working on return target: 0.15542168674698795%
# Currently working on return target: 0.15662650602409636%
# Currently working on return target: 0.1578313253012048%
# Currently working on return target: 0.15903614457831325%
# Currently working on return target: 0.16024096385542166%
# Currently working on return target: 0.1614457831325301%
# Currently working on return target: 0.16265060240963855%
# Currently working on return target: 0.16385542168674697%
# Currently working on return target: 0.1650602409638554%
# Currently working on return target: 0.16626506024096385%
# Currently working on return target: 0.16746987951807227%
# Currently working on return target: 0.1686746987951807%
# Currently working on return target: 0.16987951807228915%
# Currently working on return target: 0.17108433734939757%
# Currently working on return target: 0.172289156626506%
# Currently working on return target: 0.17349397590361443%
# Currently working on return target: 0.17469879518072287%
# Currently working on return target: 0.17590361445783131%
# Currently working on return target: 0.17710843373493973%
# Currently working on return target: 0.17831325301204817%
# Currently working on return target: 0.17951807228915662%
# Currently working on return target: 0.18072289156626503%
# Currently working on return target: 0.18192771084337347%
# Currently working on return target: 0.18313253012048192%
# Currently working on return target: 0.18433734939759033%
# Currently working on return target: 0.18554216867469878%
# Currently working on return target: 0.18674698795180722%
# Currently working on return target: 0.18795180722891563%
# Currently working on return target: 0.18915662650602408%
# Currently working on return target: 0.19036144578313252%
# Currently working on return target: 0.19156626506024094%
# Currently working on return target: 0.19277108433734938%
# Currently working on return target: 0.19397590361445782%
# Currently working on return target: 0.19518072289156624%
# Currently working on return target: 0.19638554216867468%
# Currently working on return target: 0.19759036144578312%
# Currently working on return target: 0.19879518072289154%
# Currently working on return target: 0.19999999999999998%
# Currently working on return target: 0.20120481927710843%
# Currently working on return target: 0.20240963855421684%
# Currently working on return target: 0.20361445783132529%
# Currently working on return target: 0.20481927710843373%
# Currently working on return target: 0.20602409638554214%
# Currently working on return target: 0.2072289156626506%
# Currently working on return target: 0.20843373493975903%
# Currently working on return target: 0.20963855421686745%
# Currently working on return target: 0.2108433734939759%
# Currently working on return target: 0.21204819277108433%
# Currently working on return target: 0.21325301204819275%
# Currently working on return target: 0.2144578313253012%
# Currently working on return target: 0.2156626506024096%
# Currently working on return target: 0.21686746987951805%
# Currently working on return target: 0.2180722891566265%
# Currently working on return target: 0.2192771084337349%
# Currently working on return target: 0.22048192771084335%
# Currently working on return target: 0.2216867469879518%
# Currently working on return target: 0.2228915662650602%
# Currently working on return target: 0.22409638554216865%
# Currently working on return target: 0.2253012048192771%
# Currently working on return target: 0.2265060240963855%
# Currently working on return target: 0.22771084337349395%
# Currently working on return target: 0.2289156626506024%
# Currently working on return target: 0.2301204819277108%
# Currently working on return target: 0.23132530120481926%
# Currently working on return target: 0.2325301204819277%
# Currently working on return target: 0.23373493975903611%
# Currently working on return target: 0.23493975903614456%
# Currently working on return target: 0.236144578313253%
# Currently working on return target: 0.23734939759036142%
# Currently working on return target: 0.23855421686746986%
# Currently working on return target: 0.2397590361445783%
# Currently working on return target: 0.24096385542168672%
# Currently working on return target: 0.24216867469879516%
# Currently working on return target: 0.2433734939759036%
# Currently working on return target: 0.24457831325301202%
# Currently working on return target: 0.24578313253012046%
# Currently working on return target: 0.2469879518072289%
# Currently working on return target: 0.24819277108433732%
# Currently working on return target: 0.24939759036144576%
# Currently working on return target: 0.2506024096385542%
# Currently working on return target: 0.25180722891566265%
# Currently working on return target: 0.25301204819277107%
# Currently working on return target: 0.2542168674698795%
# Currently working on return target: 0.25542168674698795%
# Currently working on return target: 0.25662650602409637%
# Currently working on return target: 0.2578313253012048%
# Currently working on return target: 0.25903614457831325%
# Currently working on return target: 0.26024096385542167%
# Currently working on return target: 0.2614457831325301%
# Currently working on return target: 0.26265060240963856%
# Currently working on return target: 0.26385542168674697%
# Currently working on return target: 0.2650602409638554%
# Currently working on return target: 0.26626506024096386%
# Currently working on return target: 0.2674698795180723%
# Currently working on return target: 0.2686746987951807%
# Currently working on return target: 0.26987951807228916%
# Currently working on return target: 0.2710843373493976%
# Currently working on return target: 0.272289156626506%
# Currently working on return target: 0.2734939759036144%
# Currently working on return target: 0.2746987951807229%
# Currently working on return target: 0.2759036144578313%
# Currently working on return target: 0.2771084337349397%
# Currently working on return target: 0.2783132530120482%
# Currently working on return target: 0.2795180722891566%
# Currently working on return target: 0.280722891566265%
# Currently working on return target: 0.2819277108433735%
# Currently working on return target: 0.2831325301204819%
# Currently working on return target: 0.2843373493975903%
# Currently working on return target: 0.2855421686746988%
# Currently working on return target: 0.2867469879518072%
# Currently working on return target: 0.2879518072289156%
# Currently working on return target: 0.2891566265060241%
# Currently working on return target: 0.2903614457831325%
# Currently working on return target: 0.2915662650602409%
# Currently working on return target: 0.2927710843373494%
# Currently working on return target: 0.2939759036144578%
# Currently working on return target: 0.2951807228915662%
# Currently working on return target: 0.2963855421686747%
# Currently working on return target: 0.2975903614457831%
# Currently working on return target: 0.2987951807228915%
# Currently working on return target: 0.3%

# %%
scttr_plt = np.zeros((3,2500))
i = 0
for weights in graph:
    scttr_plt[0,i] = graph[i][0]
    scttr_plt[1,i] = graph[i][1]
    scttr_plt[2,i] = graph[i][2]
    i += 1

# %% [markdown]
# Comparing the bottom two contours, representating maximum concentration limits of 10% and 15% respectively, the graph indicates that the model is being forced to invest into sub-optimal securities with inferior risk-reward ratios. This is evidenced by model portfolios that for the same expected return, portfolios with a 15% limit have lower expected volatility than portfolios with a 10% limit.
#
# However, as the position limit is raised to 20% and 25% respectively, it is observed that the minimum volatility increases. An upward hill is visualized from the contour plot. This indicates that the model is willing to concentrate its bets on higher volatility stocks in an effort to seek greater expected returns. Whether or not this is "good" will be a judgment call based on personal views on risk and return.
#
# As the maximum concentration limit exceeds 25%, there's no additional difference in the optimum MVO portfolio.

# %%
fig = plt.figure(figsize=(10,7))
ax = fig.add_subplot(111,projection="3d")
ax.scatter3D(xs=scttr_plt[0,:], ys=scttr_plt[1,:], zs=scttr_plt[2,:], c=scttr_plt[2,:], 
             marker="o", cmap='plasma',s=20, alpha=0.3)
ax.view_init(elev=0, azim=0)

ax.set_xlabel("Return")
ax.set_ylabel("Volatility")
ax.set_zlabel("Max Position Concentration")
# Out:
# Text(0.5, 0, 'Max Position Concentration')

# %% [markdown]
# Depiction of the optimum MVO portfolio using level sets. Each contour is separately colour differentiated.

# %%
fig = plt.figure(figsize=(20,14))
ax = fig.add_subplot(111,projection="3d")
ax.scatter3D(xs=scttr_plt[0,:], ys=scttr_plt[1,:], zs=scttr_plt[2,:], c=scttr_plt[2,:], marker="o", cmap='plasma',s=20, alpha=0.3)
ax.view_init(elev=90, azim=0)
ax.invert_xaxis()

ax.set_xlabel("Return")
ax.set_ylabel("Volatility")
ax.set_zlabel("Max Position Concentration")
# Out:
# Text(0.5, 0, 'Max Position Concentration')

# %% [markdown]
# Bird's eye view

# %%
fig = plt.figure(figsize=(10,7))
ax = fig.add_subplot(111,projection="3d")
ax.scatter3D(xs=scttr_plt[0,:], ys=scttr_plt[1,:], zs=scttr_plt[2,:], c=scttr_plt[2,:], 
             marker="o", cmap='plasma',s=20, alpha=0.3)
ax.view_init(elev=45, azim=0)
ax.invert_xaxis()

ax.set_xlabel("Return")
ax.set_ylabel("Volatility")
ax.set_zlabel("Max Position Concentration")
# Out:
# Text(0.5, 0, 'Max Position Concentration')

# %% [markdown]
# 45° view of possible portfolios based on their risk, return and maximum portfolio concentration

# %%
graph = surfaceMVO(expected_returns, cov_matrix, 0.3, 0.15)
# Out:
# Progress currentlly at 0.0%
